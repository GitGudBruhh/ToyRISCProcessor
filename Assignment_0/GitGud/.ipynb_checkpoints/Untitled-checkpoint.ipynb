# %%
import subprocess
import numpy as np
import matplotlib.pyplot as plt
import csv

for border_width in range(5, 200, 5):
    for sensor_prob_percent_val in range(0, 100, 5):
        sensor_prob = sensor_prob_percent_val/100
        print(border_width, sensor_prob)
        subprocess.call(['javac', 'Main.java'])
        subprocess.call(['java', 'Main', str(border_width), str(sensor_prob), 'output.txt'])

width_list = []
prob_list = []
time_list = []

with open('output.txt', newline='') as csvfile:
    read_obj = csv.reader(csvfile, delimiter=',', quotechar='|')

    for row in read_obj:
        width_list.append(int(row[0]))
        prob_list.append(float(row[1]))
        time_list.append(float(row[2]))

width_array = np.array(width_list)
prob_array = np.array(prob_list)
time_array = np.array(time_list)
# Out:
# 5 0.0
# 5 0.05
# 5 0.1
# 5 0.15
# 5 0.2
# 5 0.25
# 5 0.3
# 5 0.35
# 5 0.4
# 5 0.45
# 5 0.5
# 5 0.55
# 5 0.6
# 5 0.65
# 5 0.7
# 5 0.75
# 5 0.8
# 5 0.85
# 5 0.9
# 5 0.95
# 10 0.0
# 10 0.05
# 10 0.1
# 10 0.15
# 10 0.2
# 10 0.25
# 10 0.3
# 10 0.35
# 10 0.4
# 10 0.45
# 10 0.5
# 10 0.55
# 10 0.6
# 10 0.65
# 10 0.7
# 10 0.75
# 10 0.8
# 10 0.85
# 10 0.9
# 10 0.95
# 15 0.0
# 15 0.05
# 15 0.1
# 15 0.15
# 15 0.2
# 15 0.25
# 15 0.3
# 15 0.35
# 15 0.4
# 15 0.45
# 15 0.5
# 15 0.55
# 15 0.6
# 15 0.65
# 15 0.7
# 15 0.75
# 15 0.8
# 15 0.85
# 15 0.9
# 15 0.95
# 20 0.0
# 20 0.05
# 20 0.1
# 20 0.15
# 20 0.2
# 20 0.25
# 20 0.3
# 20 0.35
# 20 0.4
# 20 0.45
# 20 0.5
# 20 0.55
# 20 0.6
# 20 0.65
# 20 0.7
# 20 0.75
# 20 0.8
# 20 0.85
# 20 0.9
# 20 0.95
# 25 0.0
# 25 0.05
# 25 0.1
# 25 0.15
# 25 0.2
# 25 0.25
# 25 0.3
# 25 0.35
# 25 0.4
# 25 0.45
# 25 0.5
# 25 0.55
# 25 0.6
# 25 0.65
# 25 0.7
# 25 0.75
# 25 0.8
# 25 0.85
# 25 0.9
# 25 0.95
# 30 0.0
# 30 0.05
# 30 0.1
# 30 0.15
# 30 0.2
# 30 0.25
# 30 0.3
# 30 0.35
# 30 0.4
# 30 0.45
# 30 0.5
# 30 0.55
# 30 0.6
# 30 0.65
# 30 0.7
# 30 0.75
# 30 0.8
# 30 0.85
# 30 0.9
# 30 0.95
# 35 0.0
# 35 0.05
# 35 0.1
# 35 0.15
# 35 0.2
# 35 0.25
# 35 0.3
# 35 0.35
# 35 0.4
# 35 0.45
# 35 0.5
# 35 0.55
# 35 0.6
# 35 0.65
# 35 0.7
# 35 0.75
# 35 0.8
# 35 0.85
# 35 0.9
# 35 0.95
# 40 0.0
# 40 0.05
# 40 0.1
# 40 0.15
# 40 0.2
# 40 0.25
# 40 0.3
# 40 0.35
# 40 0.4
# 40 0.45
# 40 0.5
# 40 0.55
# 40 0.6
# 40 0.65
# 40 0.7
# 40 0.75
# 40 0.8
# 40 0.85
# 40 0.9
# 40 0.95
# 45 0.0
# 45 0.05
# 45 0.1
# 45 0.15
# 45 0.2
# 45 0.25
# 45 0.3
# 45 0.35
# 45 0.4
# 45 0.45
# 45 0.5
# 45 0.55
# 45 0.6
# 45 0.65
# 45 0.7
# 45 0.75
# 45 0.8
# 45 0.85
# 45 0.9
# 45 0.95
# 50 0.0
# 50 0.05
# 50 0.1
# 50 0.15
# 50 0.2
# 50 0.25
# 50 0.3
# 50 0.35
# 50 0.4
# 50 0.45
# 50 0.5
# 50 0.55
# 50 0.6
# 50 0.65
# 50 0.7
# 50 0.75
# 50 0.8
# 50 0.85
# 50 0.9
# 50 0.95
# 55 0.0
# 55 0.05
# 55 0.1
# 55 0.15
# 55 0.2
# 55 0.25
# 55 0.3
# 55 0.35
# 55 0.4
# 55 0.45
# 55 0.5
# 55 0.55
# 55 0.6
# 55 0.65
# 55 0.7
# 55 0.75
# 55 0.8
# 55 0.85
# 55 0.9
# 55 0.95
# 60 0.0
# 60 0.05
# 60 0.1
# 60 0.15
# 60 0.2
# 60 0.25
# 60 0.3
# 60 0.35
# 60 0.4
# 60 0.45
# 60 0.5
# 60 0.55
# 60 0.6
# 60 0.65
# 60 0.7
# 60 0.75
# 60 0.8
# 60 0.85
# 60 0.9
# 60 0.95
# 65 0.0
# 65 0.05
# 65 0.1
# 65 0.15
# 65 0.2
# 65 0.25
# 65 0.3
# 65 0.35
# 65 0.4
# 65 0.45
# 65 0.5
# 65 0.55
# 65 0.6
# 65 0.65
# 65 0.7
# 65 0.75
# 65 0.8
# 65 0.85
# 65 0.9
# 65 0.95
# 70 0.0
# 70 0.05
# 70 0.1
# 70 0.15
# 70 0.2
# 70 0.25
# 70 0.3
# 70 0.35
# 70 0.4
# 70 0.45
# 70 0.5
# 70 0.55
# 70 0.6
# 70 0.65
# 70 0.7
# 70 0.75
# 70 0.8
# 70 0.85
# 70 0.9
# 70 0.95
# 75 0.0
# 75 0.05
# 75 0.1
# 75 0.15
# 75 0.2
# 75 0.25
# 75 0.3
# 75 0.35
# 75 0.4
# 75 0.45
# 75 0.5
# 75 0.55
# 75 0.6
# 75 0.65
# 75 0.7
# 75 0.75
# 75 0.8
# 75 0.85
# 75 0.9
# 75 0.95
# 80 0.0
# 80 0.05
# 80 0.1
# 80 0.15
# 80 0.2
# 80 0.25
# 80 0.3
# 80 0.35
# 80 0.4
# 80 0.45
# 80 0.5
# 80 0.55
# 80 0.6
# 80 0.65
# 80 0.7
# 80 0.75
# 80 0.8
# 80 0.85
# 80 0.9
# 80 0.95
# 85 0.0
# 85 0.05
# 85 0.1
# 85 0.15
# 85 0.2
# 85 0.25
# 85 0.3
# 85 0.35
# 85 0.4
# 85 0.45
# 85 0.5
# 85 0.55
# 85 0.6
# 85 0.65
# 85 0.7
# 85 0.75
# 85 0.8
# 85 0.85
# 85 0.9
# 85 0.95
# 90 0.0
# 90 0.05
# 90 0.1
# 90 0.15
# 90 0.2
# 90 0.25
# 90 0.3
# 90 0.35
# 90 0.4
# 90 0.45
# 90 0.5
# 90 0.55
# 90 0.6
# 90 0.65
# 90 0.7
# 90 0.75
# 90 0.8
# 90 0.85
# 90 0.9
# 90 0.95
# 95 0.0
# 95 0.05
# 95 0.1
# 95 0.15
# 95 0.2
# 95 0.25
# 95 0.3
# 95 0.35
# 95 0.4
# 95 0.45
# 95 0.5
# 95 0.55
# 95 0.6
# 95 0.65
# 95 0.7
# 95 0.75
# 95 0.8
# 95 0.85
# 95 0.9
# 95 0.95
# 100 0.0
# 100 0.05
# 100 0.1
# 100 0.15
# 100 0.2
# 100 0.25
# 100 0.3
# 100 0.35
# 100 0.4
# 100 0.45
# 100 0.5
# 100 0.55
# 100 0.6
# 100 0.65
# 100 0.7
# 100 0.75
# 100 0.8
# 100 0.85
# 100 0.9
# 100 0.95
# 105 0.0
# 105 0.05
# 105 0.1
# 105 0.15
# 105 0.2
# 105 0.25
# 105 0.3
# 105 0.35
# 105 0.4
# 105 0.45
# 105 0.5
# 105 0.55
# 105 0.6
# 105 0.65
# 105 0.7
# 105 0.75
# 105 0.8
# 105 0.85
# 105 0.9
# 105 0.95
# 110 0.0
# 110 0.05
# 110 0.1
# 110 0.15
# 110 0.2
# 110 0.25
# 110 0.3
# 110 0.35
# 110 0.4
# 110 0.45
# 110 0.5
# 110 0.55
# 110 0.6
# 110 0.65
# 110 0.7
# 110 0.75
# 110 0.8
# 110 0.85
# 110 0.9
# 110 0.95
# 115 0.0
# 115 0.05
# 115 0.1
# 115 0.15
# 115 0.2
# 115 0.25
# 115 0.3
# 115 0.35
# 115 0.4
# 115 0.45
# 115 0.5
# 115 0.55
# 115 0.6
# 115 0.65
# 115 0.7
# 115 0.75
# 115 0.8
# 115 0.85
# 115 0.9
# 115 0.95
# 120 0.0
# 120 0.05
# 120 0.1
# 120 0.15
# 120 0.2
# 120 0.25
# 120 0.3
# 120 0.35
# 120 0.4
# 120 0.45
# 120 0.5
# 120 0.55
# 120 0.6
# 120 0.65
# 120 0.7
# 120 0.75
# 120 0.8
# 120 0.85
# 120 0.9
# 120 0.95
# 125 0.0
# 125 0.05
# 125 0.1
# 125 0.15
# 125 0.2
# 125 0.25
# 125 0.3
# 125 0.35
# 125 0.4
# 125 0.45
# 125 0.5
# 125 0.55
# 125 0.6
# 125 0.65
# 125 0.7
# 125 0.75
# 125 0.8
# 125 0.85
# 125 0.9
# 125 0.95
# 130 0.0
# 130 0.05
# 130 0.1
# 130 0.15
# 130 0.2
# 130 0.25
# 130 0.3
# 130 0.35
# 130 0.4
# 130 0.45
# 130 0.5
# 130 0.55
# 130 0.6
# 130 0.65
# 130 0.7
# 130 0.75
# 130 0.8
# 130 0.85
# 130 0.9
# 130 0.95
# 135 0.0
# 135 0.05
# 135 0.1
# 135 0.15
# 135 0.2
# 135 0.25
# 135 0.3
# 135 0.35
# 135 0.4
# 135 0.45
# 135 0.5
# 135 0.55
# 135 0.6
# 135 0.65
# 135 0.7
# 135 0.75
# 135 0.8
# 135 0.85
# 135 0.9
# 135 0.95
# 140 0.0
# 140 0.05
# 140 0.1
# 140 0.15
# 140 0.2
# 140 0.25
# 140 0.3
# 140 0.35
# 140 0.4
# 140 0.45
# 140 0.5
# 140 0.55
# 140 0.6
# 140 0.65
# 140 0.7
# 140 0.75
# 140 0.8
# 140 0.85
# 140 0.9
# 140 0.95
# 145 0.0
# 145 0.05
# 145 0.1
# 145 0.15
# 145 0.2
# 145 0.25
# 145 0.3
# 145 0.35
# 145 0.4
# 145 0.45
# 145 0.5
# 145 0.55
# 145 0.6
# 145 0.65
# 145 0.7
# 145 0.75
# 145 0.8
# 145 0.85
# 145 0.9
# 145 0.95
# 150 0.0
# 150 0.05
# 150 0.1
# 150 0.15
# 150 0.2
# 150 0.25
# 150 0.3
# 150 0.35
# 150 0.4
# 150 0.45
# 150 0.5
# 150 0.55
# 150 0.6
# 150 0.65
# 150 0.7
# 150 0.75
# 150 0.8
# 150 0.85
# 150 0.9
# 150 0.95
# 155 0.0
# 155 0.05
# 155 0.1
# 155 0.15
# 155 0.2
# 155 0.25
# 155 0.3
# 155 0.35
# 155 0.4
# 155 0.45
# 155 0.5
# 155 0.55
# 155 0.6
# 155 0.65
# 155 0.7
# 155 0.75
# 155 0.8
# 155 0.85
# 155 0.9
# 155 0.95
# 160 0.0
# 160 0.05
# 160 0.1
# 160 0.15
# 160 0.2
# 160 0.25
# 160 0.3
# 160 0.35
# 160 0.4
# 160 0.45
# 160 0.5
# 160 0.55
# 160 0.6
# 160 0.65
# 160 0.7
# 160 0.75
# 160 0.8
# 160 0.85
# 160 0.9
# 160 0.95
# 165 0.0
# 165 0.05
# 165 0.1
# 165 0.15
# 165 0.2
# 165 0.25
# 165 0.3
# 165 0.35
# 165 0.4
# 165 0.45
# 165 0.5
# 165 0.55
# 165 0.6
# 165 0.65
# 165 0.7
# 165 0.75
# 165 0.8
# 165 0.85
# 165 0.9
# 165 0.95
# 170 0.0
# 170 0.05
# 170 0.1
# 170 0.15
# 170 0.2
# 170 0.25
# 170 0.3
# 170 0.35
# 170 0.4
# 170 0.45
# 170 0.5
# 170 0.55
# 170 0.6
# 170 0.65
# 170 0.7
# 170 0.75
# 170 0.8
# 170 0.85
# 170 0.9
# 170 0.95
# 175 0.0
# 175 0.05
# 175 0.1
# 175 0.15
# 175 0.2
# 175 0.25
# 175 0.3
# 175 0.35
# 175 0.4
# 175 0.45
# 175 0.5
# 175 0.55
# 175 0.6
# 175 0.65
# 175 0.7
# 175 0.75
# 175 0.8
# 175 0.85
# 175 0.9
# 175 0.95
# 180 0.0
# 180 0.05
# 180 0.1
# 180 0.15
# 180 0.2
# 180 0.25
# 180 0.3
# 180 0.35
# 180 0.4
# 180 0.45
# 180 0.5
# 180 0.55
# 180 0.6
# 180 0.65
# 180 0.7
# 180 0.75
# 180 0.8
# 180 0.85
# 180 0.9
# 180 0.95
# 185 0.0
# 185 0.05
# 185 0.1
# 185 0.15
# 185 0.2
# 185 0.25
# 185 0.3
# 185 0.35
# 185 0.4
# 185 0.45
# 185 0.5
# 185 0.55
# 185 0.6
# 185 0.65
# 185 0.7
# 185 0.75
# 185 0.8
# 185 0.85
# 185 0.9
# 185 0.95
# 190 0.0
# 190 0.05
# 190 0.1
# 190 0.15
# 190 0.2
# 190 0.25
# 190 0.3
# 190 0.35
# 190 0.4
# 190 0.45
# 190 0.5
# 190 0.55
# 190 0.6
# 190 0.65
# 190 0.7
# 190 0.75
# 190 0.8
# 190 0.85
# 190 0.9
# 190 0.95
# 195 0.0
# 195 0.05
# 195 0.1
# 195 0.15
# 195 0.2
# 195 0.25
# 195 0.3
# 195 0.35
# 195 0.4
# 195 0.45
# 195 0.5
# 195 0.55
# 195 0.6
# 195 0.65
# 195 0.7
# 195 0.75
# 195 0.8
# 195 0.85
# 195 0.9
# 195 0.95

# %%
f_width_prob_list = []
f_width_time_list = []

for i in range(len(width_array)):
    if(width_array[i] == 50):
        f_width_prob_list.append(prob_array[i])
        f_width_time_list.append(time_array[i])

f_width_prob_array = np.array(f_width_prob_list)
f_width_time_array = np.array(f_width_time_list)

print(f_width_time_array)

plt.style.use('classic')

plt.figure(figsize=(6,4))
plt.plot(f_width_prob_array, f_width_time_array)
plt.xlabel("Probability")
plt.ylabel("Time")
plt.title("Time vs Probability - Width: 50")
plt.show()
# Out:
# [  500.   522.   532.   594.   650.   668.   752.   808.   882.   992.
#   1082.  1344.  1532.  1968.  2604.  3418.  5466.  9172. 19006. 72348.]

# %%
f_prob_width_list = []
f_prob_time_list = []

for i in range(len(prob_array)):
    if(prob_array[i] == 0.5):
        f_prob_width_list.append(width_array[i])
        f_prob_time_list.append(time_array[i])

f_prob_width_array = np.array(f_prob_width_list)
f_prob_time_array = np.array(f_prob_time_list)

plt.figure(figsize=(6,4))
plt.plot(f_prob_width_array, f_prob_time_array)
plt.xlabel("Width")
plt.ylabel("Time")
plt.title("Time vs Width - Probability: 0.5")
plt.show()

# %%
from mpl_toolkits import mplot3d
# import matplotlib
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# mkfunc = lambda x, pos: '%1.1fM' % (x * 1e-6) if x >= 1e6 else '%1.1fK' % (x * 1e-3) if x >= 1e3 else '%1.1f' % x
# mkformatter = matplotlib.ticker.FuncFormatter(mkfunc)
# ax.yaxis.set_major_formatter(mkformatter)

# ax.set_zlim[-10, 300000]
ax.scatter(width_array, prob_array, time_array)
plt.xlabel("Width")
plt.ylabel("Probability")
plt.title("Time vs (Width x Probability)")
# plt.zlabel("Probability")
plt.show()


# ax = matplotlib.pyplot.gca()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 10
#       4 ax = fig.add_subplot(projection='3d')
#       6 # mkfunc = lambda x, pos: '%1.1fM' % (x * 1e-6) if x >= 1e6 else '%1.1fK' % (x * 1e-3) if x >= 1e3 else '%1.1f' % x
#       7 # mkformatter = matplotlib.ticker.FuncFormatter(mkfunc)
#       8 # ax.yaxis.set_major_formatter(mkformatter)
# ---> 10 ax.set_zlim[-10, 300000]
#      11 ax.scatter(width_array, prob_array, time_array)
#      12 plt.xlabel("Width")
#
# TypeError: 'method' object is not subscriptable
